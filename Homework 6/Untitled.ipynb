# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch import cuda
pin_memory=False 

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
cuda.get_device_name()
# Out:
# cuda
# 'NVIDIA GeForce GTX 1050 Ti with Max-Q Design'

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from PIL import __version__
print(__version__)

import PIL

from PIL import __version__
PIL.PILLOW_VERSION = __version__

print(PIL.PILLOW_VERSION)
# Out:
# 9.2.0
# 9.2.0

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

# %%
from torchvision import datasets
data_path = 'C:/Users/alway/Documents/GitHub/ECGR-4105/Homework 6/'
cifar10 = datasets.CIFAR10(data_path, train=True, download=True) # <1>
cifar10_val = datasets.CIFAR10(data_path, train=False, download=True) # <2>
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from torchvision import datasets, transforms
data_path = 'C:/Users/alway/Documents/GitHub/ECGR-4105/Homework 6/'
cifar10 = datasets.CIFAR10(
    data_path, train=True, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
]))

from torchvision import datasets, transforms
data_path = 'C:/Users/alway/Documents/GitHub/ECGR-4105/Homework 6/'
cifar10_val = datasets.CIFAR10(
    data_path, train=False, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
]))

# %%
model = nn.Sequential(
            nn.Linear(3072, 512),
            nn.Tanh(),
            nn.Linear(512, 10),
            nn.LogSoftmax(dim=1))
model.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=3072, out_features=512, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=512, out_features=10, bias=True)
#   (3): LogSoftmax(dim=1)
# )

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=True)

# %%
learning_rate = 1e-3

optimizer = optim.SGD(model.parameters(), lr=learning_rate)

loss_fn = nn.NLLLoss()

n_epochs = 300

for epoch in range(n_epochs):
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        loss = loss_fn(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print('Epoch %d, Loss %f' % (epoch, float(loss)))
# Out:
# Epoch 0, Loss 1.664006
# Epoch 1, Loss 2.323670
# Epoch 2, Loss 1.843419
# Epoch 3, Loss 1.895159
# Epoch 4, Loss 1.808575
# Epoch 5, Loss 1.946157
# Epoch 6, Loss 2.161470
# Epoch 7, Loss 1.342212
# Epoch 8, Loss 1.582777
# Epoch 9, Loss 1.837864
# Epoch 10, Loss 1.471713
# Epoch 11, Loss 1.534099
# Epoch 12, Loss 1.334161
# Epoch 13, Loss 1.568626
# Epoch 14, Loss 2.075408
# Epoch 15, Loss 1.371356
# Epoch 16, Loss 1.965272
# Epoch 17, Loss 1.856880
# Epoch 18, Loss 1.596603
# Epoch 19, Loss 1.471521
# Epoch 20, Loss 1.558038
# Epoch 21, Loss 1.401522
# Epoch 22, Loss 1.705506
# Epoch 23, Loss 1.300258
# Epoch 24, Loss 1.328559
# Epoch 25, Loss 1.822546
# Epoch 26, Loss 1.612357
# Epoch 27, Loss 1.826273
# Epoch 28, Loss 1.105163
# Epoch 29, Loss 1.151474
# Epoch 30, Loss 1.648778
# Epoch 31, Loss 1.875822
# Epoch 32, Loss 1.554710
# Epoch 33, Loss 1.746117
# Epoch 34, Loss 2.183022
# Epoch 35, Loss 1.059631
# Epoch 36, Loss 1.932431
# Epoch 37, Loss 1.567127
# Epoch 38, Loss 2.072687
# Epoch 39, Loss 1.460155
# Epoch 40, Loss 1.517547
# Epoch 41, Loss 1.366709
# Epoch 42, Loss 1.571831
# Epoch 43, Loss 1.479453
# Epoch 44, Loss 1.185787
# Epoch 45, Loss 1.334312
# Epoch 46, Loss 1.746610
# Epoch 47, Loss 1.510634
# Epoch 48, Loss 1.252092
# Epoch 49, Loss 1.668943
# Epoch 50, Loss 1.732266
# Epoch 232, Loss 0.607376
# Epoch 233, Loss 0.530988
# Epoch 234, Loss 0.622197
# Epoch 235, Loss 0.765913
# Epoch 236, Loss 0.473436
# Epoch 237, Loss 0.382003
# Epoch 238, Loss 0.495220
# Epoch 239, Loss 1.012457
# Epoch 240, Loss 0.602647
# Epoch 241, Loss 0.851228
# Epoch 242, Loss 0.502354
# Epoch 243, Loss 0.581761
# Epoch 244, Loss 0.469348
# Epoch 245, Loss 0.524922
# Epoch 246, Loss 0.861966
# Epoch 247, Loss 0.636018
# Epoch 248, Loss 0.650299
# Epoch 249, Loss 0.399856
# Epoch 250, Loss 0.508999
# Epoch 251, Loss 0.834540
# Epoch 252, Loss 0.622743
# Epoch 253, Loss 0.301290
# Epoch 254, Loss 0.805358
# Epoch 255, Loss 0.807833
# Epoch 256, Loss 1.010850
# Epoch 257, Loss 0.456944
# Epoch 258, Loss 0.481606
# Epoch 259, Loss 0.488094
# Epoch 260, Loss 0.635860
# Epoch 261, Loss 0.580627
# Epoch 262, Loss 0.697878
# Epoch 263, Loss 0.394101
# Epoch 264, Loss 0.412004
# Epoch 265, Loss 0.719948
# Epoch 266, Loss 0.581189
# Epoch 267, Loss 0.831098
# Epoch 268, Loss 0.733464
# Epoch 269, Loss 0.610144
# Epoch 270, Loss 0.424837
# Epoch 271, Loss 0.508597
# Epoch 272, Loss 0.506830
# Epoch 273, Loss 0.508954
# Epoch 274, Loss 0.641109
# Epoch 275, Loss 0.684428
# Epoch 276, Loss 0.414194
# Epoch 277, Loss 0.297740
# Epoch 278, Loss 0.494480
# Epoch 279, Loss 0.525094
# Epoch 280, Loss 0.467072
# Epoch 281, Loss 0.581560
# Epoch 282, Loss 0.810213
# Epoch 283, Loss 0.565027
# Epoch 284, Loss 0.304058
# Epoch 285, Loss 0.601305
# Epoch 286, Loss 0.382189
# Epoch 287, Loss 0.320683
# Epoch 288, Loss 0.681782
# Epoch 289, Loss 0.619866
# Epoch 290, Loss 0.504136
# Epoch 291, Loss 0.686673
# Epoch 292, Loss 0.417879
# Epoch 293, Loss 0.483814
# Epoch 294, Loss 1.028351
# Epoch 295, Loss 0.714208
# Epoch 296, Loss 0.327139
# Epoch 297, Loss 0.595362
# Epoch 298, Loss 0.310667
# Epoch 299, Loss 0.331413

# %%
model = nn.Sequential(
            nn.Linear(3072, 1024),
            nn.Tanh(),
            nn.Linear(1024, 512),
            nn.Tanh(),
            nn.Linear(512, 128),
            nn.Tanh(),
            nn.Linear(128, 10),
            nn.LogSoftmax(dim=1))
model.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=3072, out_features=1024, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=1024, out_features=512, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=512, out_features=128, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=128, out_features=10, bias=True)
#   (7): LogSoftmax(dim=1)
# )

# %%
learning_rate = 1e-3

optimizer = optim.SGD(model.parameters(), lr=learning_rate)

loss_fn = nn.NLLLoss()

n_epochs = 300

for epoch in range(n_epochs):
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        loss = loss_fn(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print('Epoch %d, Loss %f' % (epoch, float(loss)))
# Out:
# Epoch 0, Loss 2.183864
# Epoch 1, Loss 1.891667
# Epoch 2, Loss 1.922770
# Epoch 3, Loss 1.803099
# Epoch 4, Loss 2.205405
# Epoch 5, Loss 1.849406
# Epoch 6, Loss 1.745559
# Epoch 7, Loss 1.644679
# Epoch 8, Loss 1.684509
# Epoch 9, Loss 1.907374
# Epoch 10, Loss 1.918397
# Epoch 11, Loss 2.021571
# Epoch 12, Loss 1.316993
# Epoch 13, Loss 1.782898
# Epoch 14, Loss 1.741417
# Epoch 15, Loss 1.515282
# Epoch 16, Loss 1.650456
# Epoch 17, Loss 1.530072
# Epoch 18, Loss 1.903527
# Epoch 19, Loss 1.561473
# Epoch 20, Loss 1.784054
# Epoch 21, Loss 1.923088
# Epoch 22, Loss 1.712804
# Epoch 23, Loss 1.864076
# Epoch 24, Loss 1.667434
# Epoch 25, Loss 1.881118
# Epoch 26, Loss 1.912906
# Epoch 27, Loss 1.480091
# Epoch 28, Loss 1.929146
# Epoch 29, Loss 1.799189
# Epoch 30, Loss 1.935328
# Epoch 31, Loss 1.594253
# Epoch 32, Loss 1.338403
# Epoch 33, Loss 1.920889
# Epoch 34, Loss 1.489534
# Epoch 35, Loss 1.536329
# Epoch 36, Loss 1.650930
# Epoch 37, Loss 1.497845
# Epoch 38, Loss 1.419642
# Epoch 39, Loss 1.409116
# Epoch 40, Loss 1.299226
# Epoch 41, Loss 1.382236
# Epoch 42, Loss 1.941864
# Epoch 43, Loss 1.258775
# Epoch 44, Loss 1.524666
# Epoch 45, Loss 1.629562
# Epoch 46, Loss 1.565045
# Epoch 47, Loss 1.235797
# Epoch 48, Loss 1.793047
# Epoch 49, Loss 1.263577
# Epoch 50, Loss 1.165472
# Epoch 51, Loss 1.493518
# Epoch 52, Loss 1.362574
# Epoch 53, Loss 1.484039
# Epoch 54, Loss 1.885957
# Epoch 55, Loss 1.964716
# Epoch 56, Loss 1.684596
# Epoch 57, Loss 2.317770
# Epoch 58, Loss 1.561624
# Epoch 59, Loss 1.230875
# Epoch 60, Loss 1.468549
# Epoch 61, Loss 1.115842
# Epoch 62, Loss 1.756433
# Epoch 63, Loss 1.753571
# Epoch 64, Loss 1.080001
# Epoch 65, Loss 1.383756
# Epoch 66, Loss 1.406675
# Epoch 67, Loss 1.645643
# Epoch 68, Loss 1.285870
# Epoch 69, Loss 1.076184
# Epoch 70, Loss 1.464696
# Epoch 71, Loss 1.244306
# Epoch 72, Loss 1.478522
# Epoch 73, Loss 1.187115
# Epoch 74, Loss 1.531135
# Epoch 75, Loss 1.202283
# Epoch 76, Loss 1.448572
# Epoch 77, Loss 1.296628
# Epoch 78, Loss 1.200399
# Epoch 79, Loss 1.583550
# Epoch 80, Loss 0.914484
# Epoch 81, Loss 1.109533
# Epoch 82, Loss 1.411050
# Epoch 83, Loss 1.528731
# Epoch 84, Loss 1.286575
# Epoch 85, Loss 1.209444
# Epoch 86, Loss 1.363972
# Epoch 87, Loss 1.173007
# Epoch 88, Loss 1.326576
# Epoch 89, Loss 1.756594
# Epoch 90, Loss 1.055172
# Epoch 91, Loss 1.521199
# Epoch 92, Loss 1.742985
# Epoch 93, Loss 0.806701
# Epoch 94, Loss 1.630250
# Epoch 95, Loss 1.305071
# Epoch 96, Loss 1.536102
# Epoch 97, Loss 0.972752
# Epoch 98, Loss 0.958154
# Epoch 99, Loss 1.559174
# Epoch 100, Loss 1.290157
# Epoch 101, Loss 1.595581
# Epoch 102, Loss 0.821980
# Epoch 103, Loss 1.043506
# Epoch 104, Loss 0.824840
# Epoch 105, Loss 1.009603
# Epoch 106, Loss 1.222237
# Epoch 107, Loss 1.305990
# Epoch 108, Loss 1.170495
# Epoch 109, Loss 1.487697
# Epoch 110, Loss 1.258583
# Epoch 111, Loss 0.948740
# Epoch 112, Loss 1.078624
# Epoch 113, Loss 1.029569
# Epoch 114, Loss 1.058047
# Epoch 115, Loss 1.125094
# Epoch 116, Loss 1.170672
# Epoch 117, Loss 1.102921
# Epoch 118, Loss 1.083858
# Epoch 119, Loss 0.686470
# Epoch 120, Loss 1.421759
# Epoch 121, Loss 1.099860
# Epoch 122, Loss 1.321097
# Epoch 123, Loss 0.759787
# Epoch 124, Loss 0.874287
# Epoch 125, Loss 0.722441
# Epoch 126, Loss 0.758840
# Epoch 127, Loss 0.608319
# Epoch 128, Loss 0.902651
# Epoch 129, Loss 0.950462
# Epoch 130, Loss 0.950505
# Epoch 131, Loss 0.703256
# Epoch 132, Loss 0.752130
# Epoch 133, Loss 0.436855
# Epoch 134, Loss 1.198460
# Epoch 135, Loss 0.650625
# Epoch 136, Loss 0.608651
# Epoch 137, Loss 0.901405
# Epoch 138, Loss 0.887355
# Epoch 139, Loss 1.345177
# Epoch 140, Loss 0.681741
# Epoch 141, Loss 0.663709
# Epoch 142, Loss 0.773311
# Epoch 143, Loss 0.928798
# Epoch 144, Loss 0.802108
# Epoch 145, Loss 0.600947
# Epoch 146, Loss 0.431504
# Epoch 147, Loss 0.641495
# Epoch 148, Loss 0.735825
# Epoch 149, Loss 0.158040
# Epoch 150, Loss 0.295998
# Epoch 151, Loss 0.690609
# Epoch 152, Loss 0.520023
# Epoch 153, Loss 0.531049
# Epoch 154, Loss 0.654564
# Epoch 155, Loss 0.465181
# Epoch 156, Loss 0.717240
# Epoch 157, Loss 0.822348
# Epoch 158, Loss 0.364815
# Epoch 159, Loss 0.535769
# Epoch 160, Loss 0.430326
# Epoch 161, Loss 0.395705
# Epoch 162, Loss 0.525793
# Epoch 163, Loss 0.582632
# Epoch 164, Loss 0.432013
# Epoch 165, Loss 0.512573
# Epoch 166, Loss 0.211540
# Epoch 167, Loss 0.295829
# Epoch 168, Loss 0.455848
# Epoch 169, Loss 0.395070
# Epoch 170, Loss 0.270665
# Epoch 171, Loss 0.296253
# Epoch 172, Loss 0.550507
# Epoch 173, Loss 0.524898
# Epoch 174, Loss 0.239992
# Epoch 175, Loss 0.251789
# Epoch 176, Loss 0.385220
# Epoch 177, Loss 0.251646
# Epoch 178, Loss 0.404226
# Epoch 179, Loss 0.324814
# Epoch 180, Loss 0.215244
# Epoch 181, Loss 0.112984
# Epoch 182, Loss 0.339883
# Epoch 183, Loss 0.260235
# Epoch 184, Loss 0.304065
# Epoch 185, Loss 0.393150
# Epoch 186, Loss 0.418055
# Epoch 278, Loss 0.027833
# Epoch 279, Loss 0.021454
# Epoch 280, Loss 0.015324
# Epoch 281, Loss 0.033434
# Epoch 282, Loss 0.014917
# Epoch 283, Loss 0.021008
# Epoch 284, Loss 0.016748
# Epoch 285, Loss 0.022711
# Epoch 286, Loss 0.016064
# Epoch 287, Loss 0.015452
# Epoch 288, Loss 0.041554
# Epoch 289, Loss 0.012093
# Epoch 290, Loss 0.011760
# Epoch 291, Loss 0.019351
# Epoch 292, Loss 0.021327
# Epoch 293, Loss 0.018236
# Epoch 294, Loss 0.016549
# Epoch 295, Loss 0.017600
# Epoch 296, Loss 0.015524
# Epoch 297, Loss 0.009813
# Epoch 298, Loss 0.097855
# Epoch 299, Loss 0.015665

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Accuracy: %f" % (correct / total))
# Out:
# Accuracy: 0.999940

# %%
val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64,
                                         shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in val_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Val Accuracy: %f" % (correct / total))
# Out:
# Val Accuracy: 0.452700

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.act1 = nn.Tanh()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(16, 8, kernel_size=3, padding=1)
        self.act2 = nn.Tanh()
        self.pool2 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(8 * 8 * 8, 32)
        self.act3 = nn.Tanh()
        self.fc2 = nn.Linear(32, 10)

    def forward(self, x):
        out = self.pool1(self.act1(self.conv1(x)))
        out = self.pool2(self.act2(self.conv2(out)))
        out = out.view(-1, 8 * 8 * 8) # <1>
        out = self.act3(self.fc1(out))
        out = self.fc2(out)
        return out

# %%
import datetime  # <1>

def training_loop(n_epochs, optimizer, model, loss_fn, train_loader):
    for epoch in range(1, n_epochs + 1):  # <2>
        loss_train = 0.0
        for imgs, labels in train_loader:  # <3>
            imgs, labels = imgs.to(device), labels.to(device)
            
            outputs = model(imgs)  # <4>
            
            loss = loss_fn(outputs, labels)  # <5>

            optimizer.zero_grad()  # <6>
            
            loss.backward()  # <7>
            
            optimizer.step()  # <8>

            loss_train += loss.item()  # <9>

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Training loss {}'.format(
                datetime.datetime.now(), epoch,
                loss_train / len(train_loader)))  # <10>

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=True)  # <1>

model = Net().to(device=device)  #  <2>
optimizer = optim.SGD(model.parameters(), lr=1e-2)  #  <3>
loss_fn = nn.CrossEntropyLoss()  #  <4>

training_loop(  # <5>
    n_epochs = 300,
    optimizer = optimizer,
    model = model,
    loss_fn = loss_fn,
    train_loader = train_loader,
)
# Out:
# 2022-12-09 01:06:05.544996 Epoch 1, Training loss 2.0553844107691286
# 2022-12-09 01:09:41.097714 Epoch 10, Training loss 1.1962168343231807
# 2022-12-09 01:13:22.424064 Epoch 20, Training loss 1.0239679372066732
# 2022-12-09 01:16:12.549450 Epoch 30, Training loss 0.936213958446327
# 2022-12-09 01:19:03.335638 Epoch 40, Training loss 0.876223260179505
# 2022-12-09 01:21:56.905127 Epoch 50, Training loss 0.8277880147366268
# 2022-12-09 01:24:52.558706 Epoch 60, Training loss 0.79020676455077
# 2022-12-09 01:27:52.685412 Epoch 70, Training loss 0.7583490523993207
# 2022-12-09 01:30:58.939210 Epoch 80, Training loss 0.736160230567998
# 2022-12-09 01:34:06.077008 Epoch 90, Training loss 0.7159806725847752
# 2022-12-09 01:37:31.533488 Epoch 100, Training loss 0.698925267476255
# 2022-12-09 01:40:56.133647 Epoch 110, Training loss 0.6804543617741227
# 2022-12-09 01:43:45.182136 Epoch 120, Training loss 0.6662898625025664
# 2022-12-09 01:46:34.233028 Epoch 130, Training loss 0.6524272537444864
# 2022-12-09 01:49:22.933907 Epoch 140, Training loss 0.6403960287570953
# 2022-12-09 01:52:12.892895 Epoch 150, Training loss 0.6292594678109259
# 2022-12-09 01:55:01.235104 Epoch 160, Training loss 0.6183453729695372
# 2022-12-09 01:57:54.871723 Epoch 170, Training loss 0.6105454593439541
# 2022-12-09 02:00:48.373028 Epoch 180, Training loss 0.6007820054164628
# 2022-12-09 02:03:48.716849 Epoch 190, Training loss 0.5935625948793138
# 2022-12-09 02:06:52.690360 Epoch 200, Training loss 0.5850167824789081
# 2022-12-09 02:10:00.796590 Epoch 210, Training loss 0.5790590306986934
# 2022-12-09 02:13:25.528134 Epoch 220, Training loss 0.5712562177873328
# 2022-12-09 02:16:43.968365 Epoch 230, Training loss 0.5656892433190894
# 2022-12-09 02:19:33.328611 Epoch 240, Training loss 0.5588525082068065
# 2022-12-09 02:22:21.879981 Epoch 250, Training loss 0.5544722478865357
# 2022-12-09 02:25:11.059252 Epoch 260, Training loss 0.5469630439872937
# 2022-12-09 02:27:59.828873 Epoch 270, Training loss 0.5447239541946469
# 2022-12-09 02:30:50.030712 Epoch 280, Training loss 0.53754081912434
# 2022-12-09 02:33:44.070031 Epoch 290, Training loss 0.5338076853271946
# 2022-12-09 02:36:37.191102 Epoch 300, Training loss 0.5311872952658198

# %%
def validate(model, train_loader, val_loader):
  for name, loader in [("train", train_loader), ("val", val_loader)]:
    correct = 0
    total = 0
    with torch.no_grad():
      for imgs, labels in loader:
          imgs, labels = imgs.to(device), labels.to(device)
          batchsize = imgs.shape[0]
          outputs = model(imgs)
          _, predicted = torch.max(outputs, dim=1)
          total += labels.shape[0]
          correct += int((predicted == labels).sum())
    print("Accuracy {}: {:.2f}".format(name , correct / total))

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        batchsize = imgs.shape[0]
        outputs = model(imgs)
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Accuracy: %f" % (correct / total))
# Out:
# Accuracy: 0.820640

# %%
val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64,
                                           shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        batchsize = imgs.shape[0]
        outputs = model(imgs)
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Val Accuracy: %f" % (correct / total))
# Out:
# Val Accuracy: 0.820640

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.act1 = nn.Tanh()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(16, 8, kernel_size=3, padding=1)
        self.act2 = nn.Tanh()
        self.pool2 = nn.MaxPool2d(2)
        self.conv3 = nn.Conv2d(8, 3, kernel_size=3, padding=1)
        self.act3 = nn.Tanh()
        self.pool3 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(8 * 8 * 8, 32)
        self.act3 = nn.Tanh()
        self.fc2 = nn.Linear(32, 10)

    def forward(self, x):
        out = self.pool1(self.act1(self.conv1(x)))
        out = self.pool2(self.act2(self.conv2(out)))
        out = out.view(-1, 8 * 8 * 8) # <1>
        out = self.act3(self.fc1(out))
        out = self.fc2(out)
        return out

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=True)  # <1>

model = Net().to(device=device)  #  <2>
optimizer = optim.SGD(model.parameters(), lr=1e-2)  #  <3>
loss_fn = nn.CrossEntropyLoss()  #  <4>

training_loop(  # <5>
    n_epochs = 300,
    optimizer = optimizer,
    model = model,
    loss_fn = loss_fn,
    train_loader = train_loader,
)
# Out:
# 2022-12-09 02:37:26.278078 Epoch 1, Training loss 2.0443563648806813
# 2022-12-09 02:40:13.787496 Epoch 10, Training loss 1.1798793303844568
# 2022-12-09 02:43:18.602807 Epoch 20, Training loss 1.000374134086892
# 2022-12-09 02:46:36.064218 Epoch 30, Training loss 0.9186686828465718
# 2022-12-09 02:50:01.169140 Epoch 40, Training loss 0.8646462985011928
# 2022-12-09 02:53:43.359086 Epoch 50, Training loss 0.823350087036867
# 2022-12-09 02:57:41.111759 Epoch 60, Training loss 0.7904102757687459
# 2022-12-09 03:00:53.667390 Epoch 70, Training loss 0.7627444755848106
# 2022-12-09 03:03:44.542953 Epoch 80, Training loss 0.7376018536593908
# 2022-12-09 03:06:36.028567 Epoch 90, Training loss 0.7175761727649538
# 2022-12-09 03:09:31.347828 Epoch 100, Training loss 0.6969408463410405
# 2022-12-09 03:12:26.080258 Epoch 110, Training loss 0.6825138972238507
# 2022-12-09 03:15:28.467864 Epoch 120, Training loss 0.6666104776017806
# 2022-12-09 03:18:36.202923 Epoch 130, Training loss 0.6533116399860748
# 2022-12-09 03:21:52.315838 Epoch 140, Training loss 0.6424369510939664
# 2022-12-09 03:25:18.320893 Epoch 150, Training loss 0.6308273047666111
# 2022-12-09 03:28:58.429438 Epoch 160, Training loss 0.6224175714470846
# 2022-12-09 03:33:00.371687 Epoch 170, Training loss 0.6119294549193224
# 2022-12-09 03:36:13.716091 Epoch 180, Training loss 0.6030733306770739
# 2022-12-09 03:39:04.525242 Epoch 190, Training loss 0.5944965363997022
# 2022-12-09 03:41:53.048129 Epoch 200, Training loss 0.5871768615892171
# 2022-12-09 03:44:48.498406 Epoch 210, Training loss 0.5780536893307401
# 2022-12-09 03:47:43.051933 Epoch 220, Training loss 0.5732508215605451
# 2022-12-09 03:50:46.230496 Epoch 230, Training loss 0.5671828408604083
# 2022-12-09 03:53:53.084060 Epoch 240, Training loss 0.561990435833059
# 2022-12-09 03:57:07.721675 Epoch 250, Training loss 0.5560815814129837
# 2022-12-09 04:00:33.668712 Epoch 260, Training loss 0.549693708262785
# 2022-12-09 04:03:45.116068 Epoch 270, Training loss 0.5427862804030519
# 2022-12-09 04:06:32.913776 Epoch 280, Training loss 0.5424252646544095
# 2022-12-09 04:09:21.631949 Epoch 290, Training loss 0.5330709907252466
# 2022-12-09 04:12:11.363837 Epoch 300, Training loss 0.5328059468389778

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Accuracy: %f" % (correct / total))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11076\519852772.py in <module>
#       8     for imgs, labels in train_loader:
#       9         imgs, labels = imgs.to(device), labels.to(device)
# ---> 10         outputs = model(imgs.view(imgs.shape[0], -1))
#      11         _, predicted = torch.max(outputs, dim=1)
#      12         total += labels.shape[0]
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Temp\ipykernel_11076\1639331876.py in forward(self, x)
#      16
#      17     def forward(self, x):
# ---> 18         out = self.pool1(self.act1(self.conv1(x)))
#      19         out = self.pool2(self.act2(self.conv2(out)))
#      20         out = out.view(-1, 8 * 8 * 8) # <1>
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1188         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190             return forward_call(*input, **kwargs)
#    1191         # Do not call functions when jit is used
#    1192         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# RuntimeError: Expected 3D (unbatched) or 4D (batched) input to conv2d, but got input of size: [64, 3072]

# %%
val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64,
                                           shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        batchsize = imgs.shape[0]
        outputs = model(imgs)
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Val Accuracy: %f" % (correct / total))
