# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch import cuda

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
cuda.get_device_name()
device
# Out:
# device(type='cuda')

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from PIL import __version__
print(__version__)

import PIL

from PIL import __version__
PIL.PILLOW_VERSION = __version__

print(PIL.PILLOW_VERSION)
# Out:
# 9.2.0
# 9.2.0

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

# %%
from torchvision import datasets
data_path = 'C:/Users/alway/Documents/GitHub/ECGR-4105/Homework 6/'
cifar10 = datasets.CIFAR10(data_path, train=True, download=True) # <1>
cifar10_val = datasets.CIFAR10(data_path, train=False, download=True) # <2>
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from torchvision import datasets, transforms
data_path = 'C:/Users/alway/Documents/GitHub/ECGR-4105/Homework 6/'
cifar10 = datasets.CIFAR10(
    data_path, train=True, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
]))

from torchvision import datasets, transforms
data_path = 'C:/Users/alway/Documents/GitHub/ECGR-4105/Homework 6/'
cifar10 = datasets.CIFAR10(
    data_path, train=True, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
]))

# %%
model = nn.Sequential(
            nn.Linear(3072, 512),
            nn.Tanh(),
            nn.Linear(512, 10),
            nn.LogSoftmax(dim=1))
model.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=3072, out_features=512, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=512, out_features=10, bias=True)
#   (3): LogSoftmax(dim=1)
# )

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=12288,
                                           shuffle=True)

# %%
learning_rate = 1e-3

optimizer = optim.SGD(model.parameters(), lr=learning_rate)

loss_fn = nn.NLLLoss()

n_epochs = 300

for epoch in range(n_epochs):
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        loss = loss_fn(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print('Epoch %d, Loss %f' % (epoch, float(loss)))
# Out:
# Epoch 0, Loss 2.300916
# Epoch 1, Loss 2.280008
# Epoch 2, Loss 2.278069
# Epoch 3, Loss 2.239274
# Epoch 4, Loss 2.241633
# Epoch 5, Loss 2.232527
# Epoch 6, Loss 2.215139
# Epoch 7, Loss 2.198371
# Epoch 8, Loss 2.179388
# Epoch 9, Loss 2.181961
# Epoch 10, Loss 2.184881
# Epoch 11, Loss 2.165120
# Epoch 12, Loss 2.145510
# Epoch 13, Loss 2.135406
# Epoch 14, Loss 2.127228
# Epoch 15, Loss 2.115156
# Epoch 16, Loss 2.153778
# Epoch 17, Loss 2.132255
# Epoch 18, Loss 2.116176
# Epoch 19, Loss 2.114487
# Epoch 20, Loss 2.104966
# Epoch 21, Loss 2.073441
# Epoch 22, Loss 2.103538
# Epoch 23, Loss 2.109570
# Epoch 24, Loss 2.075142
# Epoch 25, Loss 2.080680
# Epoch 26, Loss 2.061895
# Epoch 27, Loss 2.070332
# Epoch 28, Loss 2.064659
# Epoch 29, Loss 2.023448
# Epoch 30, Loss 2.064324
# Epoch 31, Loss 2.059307
# Epoch 32, Loss 2.035375
# Epoch 33, Loss 2.053010
# Epoch 34, Loss 2.053169
# Epoch 35, Loss 2.091459
# Epoch 36, Loss 2.028672
# Epoch 37, Loss 2.034646
# Epoch 38, Loss 2.071221
# Epoch 39, Loss 2.046916
# Epoch 40, Loss 2.090796
# Epoch 41, Loss 2.058915
# Epoch 42, Loss 2.049749
# Epoch 43, Loss 2.060246
# Epoch 44, Loss 2.047395
# Epoch 45, Loss 2.001100
# Epoch 46, Loss 2.033268
# Epoch 47, Loss 2.013381
# Epoch 48, Loss 2.006405
# Epoch 49, Loss 2.018661
# Epoch 50, Loss 2.017319
# Epoch 51, Loss 1.994853
# Epoch 52, Loss 1.992792
# Epoch 53, Loss 1.981263
# Epoch 54, Loss 2.009511
# Epoch 55, Loss 2.001130
# Epoch 56, Loss 2.009974
# Epoch 57, Loss 2.003582
# Epoch 58, Loss 2.018717
# Epoch 59, Loss 1.967602
# Epoch 60, Loss 1.989185
# Epoch 61, Loss 2.013242
# Epoch 62, Loss 1.996590
# Epoch 63, Loss 2.027516
# Epoch 64, Loss 1.993404
# Epoch 65, Loss 2.005753
# Epoch 66, Loss 2.038980
# Epoch 67, Loss 1.997045
# Epoch 68, Loss 1.962212
# Epoch 69, Loss 1.959709
# Epoch 70, Loss 1.973595
# Epoch 71, Loss 2.002198
# Epoch 72, Loss 1.949755
# Epoch 73, Loss 1.984066
# Epoch 74, Loss 1.950176
# Epoch 75, Loss 1.934273
# Epoch 76, Loss 1.958965
# Epoch 77, Loss 1.975095
# Epoch 78, Loss 1.979807
# Epoch 79, Loss 1.986284
# Epoch 80, Loss 1.937550
# Epoch 81, Loss 1.972669
# Epoch 82, Loss 1.948138
# Epoch 83, Loss 1.920794
# Epoch 84, Loss 1.929291
# Epoch 85, Loss 1.964178
# Epoch 86, Loss 1.898326
# Epoch 87, Loss 1.944548
# Epoch 88, Loss 1.943373
# Epoch 89, Loss 1.982852
# Epoch 90, Loss 1.924198
# Epoch 91, Loss 1.915025
# Epoch 92, Loss 1.936831
# Epoch 93, Loss 1.926915
# Epoch 94, Loss 1.989753
# Epoch 95, Loss 1.960386
# Epoch 96, Loss 1.964179
# Epoch 97, Loss 1.952947
# Epoch 98, Loss 1.900945
# Epoch 99, Loss 1.953092
# Epoch 100, Loss 1.949438
# Epoch 101, Loss 1.930755
# Epoch 102, Loss 1.969075
# Epoch 103, Loss 1.889064
# Epoch 104, Loss 1.940801
# Epoch 105, Loss 1.951730
# Epoch 106, Loss 1.930244
# Epoch 107, Loss 1.955797
# Epoch 108, Loss 1.924462
# Epoch 109, Loss 1.926094
# Epoch 110, Loss 1.938631
# Epoch 111, Loss 1.945309
# Epoch 112, Loss 1.925215
# Epoch 113, Loss 1.899998
# Epoch 114, Loss 1.913607
# Epoch 115, Loss 1.937960
# Epoch 116, Loss 1.870597
# Epoch 117, Loss 1.946984
# Epoch 118, Loss 1.896680
# Epoch 119, Loss 1.898259
# Epoch 120, Loss 1.916364
# Epoch 121, Loss 1.935276
# Epoch 122, Loss 1.926537
# Epoch 123, Loss 1.896942
# Epoch 124, Loss 1.936846
# Epoch 125, Loss 1.940145
# Epoch 126, Loss 1.899458
# Epoch 127, Loss 1.870970
# Epoch 128, Loss 1.953975
# Epoch 129, Loss 1.907579
# Epoch 130, Loss 1.910541
# Epoch 131, Loss 1.926311
# Epoch 132, Loss 1.918195
# Epoch 133, Loss 1.954826
# Epoch 134, Loss 1.941831
# Epoch 135, Loss 1.916056
# Epoch 136, Loss 1.893590
# Epoch 137, Loss 1.934402
# Epoch 138, Loss 1.887473
# Epoch 139, Loss 1.926763
# Epoch 140, Loss 1.885963
# Epoch 141, Loss 1.909488
# Epoch 142, Loss 1.913072
# Epoch 143, Loss 1.885881
# Epoch 144, Loss 1.920882
# Epoch 145, Loss 1.912912
# Epoch 146, Loss 1.931874
# Epoch 147, Loss 1.890757
# Epoch 148, Loss 1.904575
# Epoch 149, Loss 1.920088
# Epoch 150, Loss 1.878152
# Epoch 151, Loss 1.903324
# Epoch 152, Loss 1.928947
# Epoch 153, Loss 1.884320
# Epoch 154, Loss 1.934940
# Epoch 155, Loss 1.904118
# Epoch 156, Loss 1.883696
# Epoch 157, Loss 1.849434
# Epoch 158, Loss 1.905667
# Epoch 159, Loss 1.839268
# Epoch 160, Loss 1.947293
# Epoch 161, Loss 1.881452
# Epoch 162, Loss 1.929552
# Epoch 163, Loss 1.910204
# Epoch 164, Loss 1.922451
# Epoch 165, Loss 1.878682
# Epoch 166, Loss 1.912889
# Epoch 167, Loss 1.858819
# Epoch 168, Loss 1.871398
# Epoch 169, Loss 1.872763
# Epoch 170, Loss 1.911163
# Epoch 171, Loss 1.874401
# Epoch 172, Loss 1.885402
# Epoch 173, Loss 1.915807
# Epoch 174, Loss 1.918130
# Epoch 175, Loss 1.877057
# Epoch 176, Loss 1.856691
# Epoch 177, Loss 1.863836
# Epoch 178, Loss 1.890558
# Epoch 179, Loss 1.845511
# Epoch 180, Loss 1.887754
# Epoch 181, Loss 1.925570
# Epoch 182, Loss 1.851320
# Epoch 183, Loss 1.905734
# Epoch 184, Loss 1.901573
# Epoch 185, Loss 1.893471
# Epoch 186, Loss 1.920195
# Epoch 187, Loss 1.862363
# Epoch 188, Loss 1.848149
# Epoch 189, Loss 1.839148
# Epoch 190, Loss 1.873801
# Epoch 191, Loss 1.866362
# Epoch 192, Loss 1.850469
# Epoch 193, Loss 1.936898
# Epoch 194, Loss 1.851678
# Epoch 195, Loss 1.835973
# Epoch 196, Loss 1.870989
# Epoch 197, Loss 1.861780
# Epoch 198, Loss 1.848269
# Epoch 199, Loss 1.844641
# Epoch 200, Loss 1.871019
# Epoch 201, Loss 1.858465
# Epoch 202, Loss 1.852078
# Epoch 203, Loss 1.901308
# Epoch 204, Loss 1.898196

# %%
model = nn.Sequential(
            nn.Linear(3072, 1024),
            nn.Tanh(),
            nn.Linear(1024, 512),
            nn.Tanh(),
            nn.Linear(512, 128),
            nn.Tanh(),
            nn.Linear(128, 10),
            nn.LogSoftmax(dim=1))
model.to(device)

# %%
learning_rate = 1e-3

optimizer = optim.SGD(model.parameters(), lr=learning_rate)

loss_fn = nn.NLLLoss()

n_epochs = 300

for epoch in range(n_epochs):
    for imgs, labels in train_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs = model(imgs.view(imgs.shape[0], -1))
        loss = loss_fn(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print('Epoch %d, Loss %f' % (epoch, float(loss)))

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Accuracy: %f" % (correct / total))

# %%
val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64,
                                         shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in val_loader:
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Val Accuracy: %f" % (correct / total))

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.act1 = nn.Tanh()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(16, 8, kernel_size=3, padding=1)
        self.act2 = nn.Tanh()
        self.pool2 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(8 * 8 * 8, 32)
        self.act3 = nn.Tanh()
        self.fc2 = nn.Linear(32, 10

    def forward(self, x):
        out = self.pool1(self.act1(self.conv1(x)))
        out = self.pool2(self.act2(self.conv2(out)))
        out = out.view(-1, 8 * 8 * 8) # <1>
        out = self.act3(self.fc1(out))
        out = self.fc2(out)
        return out

# %%
import datetime  # <1>

def training_loop(n_epochs, optimizer, model, loss_fn, train_loader):
    for epoch in range(1, n_epochs + 1):  # <2>
        loss_train = 0.0
        for imgs, labels in train_loader:  # <3>
            imgs, labels = imgs.to(device), labels.to(device)
            
            outputs = model(imgs)  # <4>
            
            loss = loss_fn(outputs, labels)  # <5>

            optimizer.zero_grad()  # <6>
            
            loss.backward()  # <7>
            
            optimizer.step()  # <8>

            loss_train += loss.item()  # <9>

        if epoch == 1 or epoch % 10 == 0:
            print('{} Epoch {}, Training loss {}'.format(
                datetime.datetime.now(), epoch,
                loss_train / len(train_loader)))  # <10>

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=True)  # <1>

model = Net().to(device=device)  #  <2>
optimizer = optim.SGD(model.parameters(), lr=1e-2)  #  <3>
loss_fn = nn.CrossEntropyLoss()  #  <4>

training_loop(  # <5>
    n_epochs = 300,
    optimizer = optimizer,
    model = model,
    loss_fn = loss_fn,
    train_loader = train_loader,
)

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Accuracy: %f" % (correct / total))

# %%
val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64,
                                         shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in val_loader:
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Val Accuracy: %f" % (correct / total))

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.act1 = nn.Tanh()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(16, 8, kernel_size=3, padding=1)
        self.act2 = nn.Tanh()
        self.pool2 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(8, 3, kernel_size=3, padding=1)
        self.act3 = nn.Tanh()
        self.pool2 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(8 * 8 * 8, 32)
        self.fc2 = nn.Linear(32, 10)

    def forward(self, x):
        out = self.pool1(self.act1(self.conv1(x)))
        out = self.pool2(self.act2(self.conv2(out)))
        out = out.view(-1, 8 * 8 * 8) # <1>
        out = self.act3(self.fc1(out))
        out = self.fc2(out)
        return out

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=True)  # <1>

model = Net().to(device=device)  #  <2>
optimizer = optim.SGD(model.parameters(), lr=1e-2)  #  <3>
loss_fn = nn.CrossEntropyLoss()  #  <4>

training_loop(  # <5>
    n_epochs = 300,
    optimizer = optimizer,
    model = model,
    loss_fn = loss_fn,
    train_loader = train_loader,
)

# %%
train_loader = torch.utils.data.DataLoader(cifar10, batch_size=64,
                                           shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in train_loader:
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Accuracy: %f" % (correct / total))

# %%
val_loader = torch.utils.data.DataLoader(cifar10_val, batch_size=64,
                                         shuffle=False)

correct = 0
total = 0

with torch.no_grad():
    for imgs, labels in val_loader:
        outputs = model(imgs.view(imgs.shape[0], -1))
        _, predicted = torch.max(outputs, dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
        
print("Val Accuracy: %f" % (correct / total))
